# %%
from __future__ import print_function

from tesserocr import PyTessBaseAPI, PSM, PT, RIL, iterate_level
from PIL import Image
import time

# %%
import tesserocr
tesserocr.tesseract_version()
# Out:
# 'tesseract 4.0.0\n leptonica-1.76.0 (Jan  8 2019, 13:41:57) [MSC v.1900 LIB Release x64]\n  libgif 5.1.4 : libjpeg 9b : libpng 1.6.35 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.3.0'

# %%
start_ = time.time()
IMAGE_PATH = "../datafiles/Page_2.jpg"
imageMAT = Image.open(IMAGE_PATH)
print("Time", time.time() - start_)
# Out:
# Time 0.03298354148864746

# %%
start = time.time()

with PyTessBaseAPI(path = "C:\\Tesseract-OCR-3\\tessdata") as api:
    api.SetImageFile('../datafiles/Page_2.jpg')
    api.SetVariable("save_blob_choices", "T")
    api.SetVariable('hocr_font_info', '1')
        
    api.Recognize()
    pi = api.AnalyseLayout()
    ri = api.GetIterator()
    print("check# 1")
    
    level = RIL.SYMBOL
    for p, r in zip(iterate_level(pi, level), iterate_level(ri, level)):
        print("check# 2")
        #print(r)
        bbox = p.BoundingBox(level)
        print("bbox:\t", bbox, r.GetUTF8Text(level))

print("TIME:\t", time.time() - start)

# %%
start = time.time()

with PyTessBaseAPI(path = r"C:\\Tesseract-OCR-3\\tessdata") as api:
        api.SetImageFile('../datafiles/Page_2.jpg')
        api.SetVariable("save_blob_choices", "T")
        api.SetVariable('hocr_font_info', '1')
        #api.SetVariable('tessedit_debug_fonts', '1')
        api.Recognize()
        #pi = api.AnalyseLayout()
        ri = api.GetIterator()
       
        #print(pi)
        print(ri)
      
        #print("FONT:\t", ri.RowAttributes())
        
        level = RIL.WORD
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes(), r.GetUTF8Text(level))
            # print(ri.)\n",
print("TIME:\t", time.time() - start)
# Out:
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 69, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 0, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 32, 'font_id': 317} b§7§T§i018
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 32, 'font_id': 317} Page
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Times_New_Roman', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 32, 'font_id': 283} 2
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 32, 'font_id': 317} of3
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 16, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 12, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 12, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 12, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 0, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 13, 'font_id': 317} text
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 1, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 316} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 316} chest
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} paIn
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Respiratory
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 70} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} shortness
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} of
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} breath
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Gastrointestinal
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New', 'bold': False, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 69} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} vomiting
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Genitourinary
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 316} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} painful
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} urination,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} leaking
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} urine,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} blood
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} in
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} urine
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} Integument
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'DejaVu_Sans_Ultra-Light', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 85} *
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} See
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} HPI
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Neurologic
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 70} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} memory
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} loss
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Musculoskeletal
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Georgia', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 22, 'font_id': 135} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} joint
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} pain
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Psychiatric
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Denies
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} depression
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 217, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 217, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 1, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Ita
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} 5
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': True, 'pointsize': 23, 'font_id': 317} BMI
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Date
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Time
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} BP
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Position
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Site
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} L\R
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} CuffSize
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} HR
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} RR
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} TEMP(F)
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} WT
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} HT
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} kg/mZ
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} BSAmZOZ
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Sat
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} HC
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 13, 'font_id': 317} Line
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 11/16/2017
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 11:52AM
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 158/70
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} Sitting
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 100-R
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} 16
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 98.2
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 165|bSOOZ
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} 5'
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} 7"
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 25.84
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 316} 1.88
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} 97%
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 72, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 2, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 24, 'font_id': 317} ﬁysmal
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 24, 'font_id': 317} Examination
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Constitutional
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Appearance
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 316} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Well-nourished,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} well
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} developed,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} alert,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} in
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} no
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} apparent
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} distress
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Head
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Face
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Head
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Normocephaliic.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Face
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New', 'bold': False, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 22, 'font_id': 69} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Atraumatic.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 20, 'font_id': 317} Eyes
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Sclerae
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} No
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} scleral
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} icterus.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Pupils
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Irises
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Trebuchet_MS', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 295} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} PERRL.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Ears,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Nose,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Mouth
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Throat
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} VHS.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Y;
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': True, 'pointsize': 26, 'font_id': 317} T95
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'DejaVu_Sans_Ultra-Light', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 85} F
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} “l0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} ’91”?
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'DejaVu_Sans_Ultra-Light', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 85} M
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} 1%
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Oral
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Cavity
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Moist
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} mucus
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} membranes.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Throat
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 26, 'font_id': 70} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} Oropharynx
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} widely
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} patent.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} 0';
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Times_New_Roman', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 26, 'font_id': 283} M
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 26, 'font_id': 317} “Eta
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Neck
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Inspection/Palpation
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New', 'bold': False, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 69} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Supple
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} neck.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Thyroid
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Georgia', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 135} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} No
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} gross
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} masses
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} visible.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Respiratory
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Respiratory
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# ...
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} hyperpigmented,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} rough,
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} pigmented
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} skin
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} on
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} anterior
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} lower
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} leg
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} diffusely
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Skin
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Subcutaneous
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Tissue
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Extremities:
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Arial_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': True, 'pointsize': 23, 'font_id': 25} I
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Right
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Upper
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Extremity
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Courier_New', 'bold': False, 'italic': False, 'underlined': False, 'monospace': True, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 69} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} ichthyosis
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} palms
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Times_New_Roman_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 284} -
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Left
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Upper
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Extremity
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Georgia', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 23, 'font_id': 135} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} ichthyosis
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} palms
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Digits
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Nails
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 316} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Hypertrophic
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} fingernails
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} toenails
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Neurologic
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} 0
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Mental
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Status
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Examination
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 316} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} Alert
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} and
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} oriented
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 23, 'font_id': 317} grossly.
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} o
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Motor
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 21, 'font_id': 317} Examination
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Century_Schoolbook_L', 'bold': False, 'italic': False, 'underlined': False, 'monospace': False, 'serif': True, 'smallcaps': False, 'pointsize': 21, 'font_id': 59} :
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 582, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 572, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 13, 'font_id': 317} eadTe
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 13, 'font_id': 317} t
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 0, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 17, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} D1g1tal
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Slgnature
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 22, 'font_id': 317} Vahdated
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 12, 'font_id': 317}
# <tesserocr._tesserocr.PyResultIterator object at 0x0000000005177C90>
# font:	 {'font_name': 'Verdana_Bold', 'bold': True, 'italic': False, 'underlined': False, 'monospace': False, 'serif': False, 'smallcaps': False, 'pointsize': 0, 'font_id': 317}
# TIME:	 6.739673852920532

# %%
start = time.time()

with PyTessBaseAPI(path = "C:\\Program Files\\Tesseract-OCR\\tessdata") as api:
        api.SetImageFile('../datafiles/Page_2.jpg')
        api.SetVariable("save_blob_choices", "T")
        api.SetVariable('hocr_font_info', '1')
        api.SetVariable('tessedit_debug_fonts', '1')
        api.Recognize()
        pi = api.AnalyseLayout()
        ri = api.GetIterator()
       
        print(pi)
        print(ri)
      
        print("FONT:\t", ri.WordFontAttributes())
        
        level = RIL.BLOCK
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes(), r.GetUTF8Text(level))
           # print(ri.)\n",
        print('--------------------------------------------- BLOCK start')
        ri = api.GetIterator()
        level = RIL.PARA
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes())
            # print(ri.)\n",
        print('--------------------------------------------- PARA start')
        ri = api.GetIterator()
        level = RIL.TEXTLINE
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes())
            # print(ri.)
        print('--------------------------------------------- TEXTLINE start')
        ri = api.GetIterator()
        level = RIL.WORD
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes())
            # print(ri.)\n",
        print('--------------------------------------------- WORD start')
                  
        ri = api.GetIterator()
        level = RIL.SYMBOL
        for r in iterate_level(ri, level):
            print(r)
            print("font:\t", r.WordFontAttributes())
            # print(ri.)
        print('--------------------------------------------- SYMBOL start')
print("TIME:\t", time.time() - start)

# %%
with PyTessBaseAPI(path="C:\\Program Files\\Tesseract-OCR\\tessdata") as api:
    start_ = time.time()
    api.SetImage(imageMAT)
    print( "Setting image time consumed ! ",time.time()- start_ )
    start_ = time.time()
    #res = api.GetUTF8Text()
    
    a = api.AnalyseLayout()
    
    print("Resource Allocation time consumed ", time.time() - start_)
    #print(api.LocateTables())
    #print(api.AllWordConfidences())
    print("Time", time.time() - start_)
# Out:
# Setting image time consumed !  0.22799992561340332
# Resource Allocation time consumed  0.8419997692108154
# Time 0.8419997692108154

# %%
with PyTessBaseAPI( path="C:\\Program Files\\Tesseract-OCR\\tessdata") as api:
    api.SetImage(imageMAT)
    #api.SetVariable("save_blob_choices", "T")
    
    ri = api.GetIterator()
    level = RIL.BLOCK
    print (ri)
    print (level)
    for r in iterate_level(ri, level):
        if r:
            symbol = r.GetUTF8Text(level)  # r == ri
            #conf = r.PolyBlockType()
            print(symbol, conf)
# Out:
# None
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9cb6a838ffeb> in <module>
#       7     print (ri)
#       8     print (level)
# ----> 9     for r in iterate_level(ri, level):
#      10         if r:
#      11             symbol = r.GetUTF8Text(level)  # r == ri
#
# tesserocr.pyx in iterate_level()
#
# AttributeError: 'NoneType' object has no attribute 'Next'

# %%
with PyTessBaseAPI() as api:
    api.SetImage(imageMAT)
    boxes = api.GetComponentImages(RIL.TEXTLINE, True)
    print('Found {} textline image components.'.format(len(boxes)))
    for i, (im, box, _, _) in enumerate(boxes):
        # im is a PIL image object
        # box is a dict with x, y, w and h keys
        api.SetRectangle(box['x'], box['y'], box['w'], box['h'])
        ocrResult = api.GetUTF8Text()
        conf = api.MeanTextConf()
        print(u"Box[{0}]: x={x}, y={y}, w={w}, h={h}, "
              "confidence: {1}, text: {2}".format(i, conf, ocrResult, **box))
# Out:
# Found 60 textline image components.
# Box[0]: x=2099, y=9, w=407, h=55, confidence: 58, text: 379879018] Page 2 of 3]
#
# Box[1]: x=244, y=111, w=383, h=38, confidence: 84, text: © Denies : chest pain
#
# Box[2]: x=169, y=162, w=215, h=35, confidence: 95, text: Respiratory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f256fe353265> in <module>
#       7         # box is a dict with x, y, w and h keys
#       8         api.SetRectangle(box['x'], box['y'], box['w'], box['h'])
# ----> 9         ocrResult = api.GetUTF8Text()
#      10         conf = api.MeanTextConf()
#      11         print(u"Box[{0}]: x={x}, y={y}, w={w}, h={h}, "
#
# KeyboardInterrupt:

# %%
with PyTessBaseAPI() as api:
    api.SetImage(imageMAT)
    api.SetVariable("save_blob_choices", "T")
    api.SetRectangle(37, 228, 548, 31)
    api.Recognize()

    ri = api.GetIterator()
    level = RIL.SYMBOL
    for r in iterate_level(ri, level):
        symbol = r.GetUTF8Text(level)  # r == ri
        conf = r.Confidence(level)
        if symbol:
            print(u'symbol {}, conf: {}'.format(symbol, conf), end='')
        indent = False
        ci = r.GetChoiceIterator()
        for c in ci:
            if indent:
                print('\t\t ', end='')
            print('\t- ', end='')
            choice = c.GetUTF8Text()  # c == ci
            print(u'{} conf: {}'.format(choice, c.Confidence()))
            indent = True
        print('---------------------------------------------')
# Out:
# symbol e, conf: 94.31781005859375	- e conf: 94.31781005859375
# ---------------------------------------------
# symbol T, conf: 90.22886657714844	- T conf: 90.22886657714844
# ---------------------------------------------
# symbol U, conf: 79.90371704101562	- U conf: 79.90371704101562
# ---------------------------------------------
# symbol N, conf: 93.25653839111328	- N conf: 93.25653839111328
# ---------------------------------------------
# symbol E, conf: 82.03719329833984	- E conf: 82.03719329833984
# ---------------------------------------------
# symbol A, conf: 93.57275390625	- A conf: 93.57275390625
# ---------------------------------------------
# symbol T, conf: 94.54393768310547	- T conf: 94.54393768310547
# ---------------------------------------------
# symbol P, conf: 93.83062744140625	- P conf: 93.83062744140625
# ---------------------------------------------
# symbol e, conf: 93.32611846923828	- e conf: 93.32611846923828
# ---------------------------------------------
# symbol  , conf: 95.0	-   conf: 95.0
# ---------------------------------------------

# %%
with PyTessBaseAPI() as api:
    api.SetImage(imageMAT)
    api.SetVariable("save_blob_choices", "T")
    api.Recognize()
    
    ri = api.GetIterator()
    level = RIL.BLOCK
    print (ri)
    print (level)
    for r in iterate_level(ri, level):
        if r:
            symbol = r.GetUTF8Text(level)  # r == ri
            #conf = r.PolyBlockType()
            print(symbol, conf)

# %%
with PyTessBaseAPI(path="C:\\Program Files\\Tesseract-OCR\\tessdata") as api:
    api.SetImage(imageMAT)
    print("check Set")
    api.SetVariable("save_blob_choices", "T")
    api.Recognize()

    print("check Rec")
    ri = api.GetIterator()
    level = RIL.BLOCK
    
    print(ri)
    print(level)
    
    for r in iterate_level(ri, level):
        symbol = r.GetUTF8Text(level)  # r == ri
        conf = r.Confidence(level)
        if symbol:
            print(u'symbol {}, conf: {}'.format(symbol, conf), end='')
        indent = False
        ci = r.GetChoiceIterator()
        for c in ci:
            if indent:
                print('\t\t ', end='')
            print('\t- ', end='')
            choice = c.GetUTF8Text()  # c == ci
            print(u'{} conf: {}'.format(choice, c.Confidence()))
            indent = True
        print('---------------------------------------------')
# Out:
# check Set

# %%
help(api.GetIterator)
# Out:
# Help on built-in function GetIterator:
#
# GetIterator(...) method of tesserocr._tesserocr.PyTessBaseAPI instance
#     Get a reading-order iterator to the results of :meth:`LayoutAnalysis` and/or
#     :meth:`Recognize`.
#
#     Returns:
#         :class:`PyResultIterator`: reading-order iterator or `None` on failure.

# %%
with PyTessBaseAPI(path="C:\\Program Files\\Tesseract-OCR\\tessdata") as api:
    api.SetImage(imageMAT)
    boxes = api.GetComponentImages(PT.TABLE, True)
    print('Found {} textline image components.'.format(len(boxes)))

# %%
boxes
# Out:
# [(<PIL.JpegImagePlugin.JpegImageFile image mode=L size=407x55 at 0x560A208>,
#   {'x': 2099, 'y': 9, 'w': 407, 'h': 55},
#   0,
#   None),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=L size=1074x723 at 0x560A278>,
#   {'x': 169, 'y': 111, 'w': 1074, 'h': 723},
#   1,
#   None),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2364x107 at 0x560A2E8>,
#   {'x': 55, 'y': 961, 'w': 2364, 'h': 107},
#   2,
#   None),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2290x52 at 0x560A358>,
#   {'x': 46, 'y': 1080, 'w': 2290, 'h': 52},
#   3,
#   None),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2343x1955 at 0x560A3C8>,
#   {'x': 49, 'y': 1238, 'w': 2343, 'h': 1955},
#   4,
#   None),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=L size=481x55 at 0x560A438>,
#   {'x': 2046, 'y': 3226, 'w': 481, 'h': 55},
#   5,
#   None)]
