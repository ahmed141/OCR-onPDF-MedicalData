# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
ocr_path = "C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread('testNoise.jpg', 0)

# %%
plt.imshow(img)

# %%
print(pytesseract.image_to_string(img))
# Out:
# . Hidden layer(s) perform classification of features
# * Sigmoid activation function
#
#
#
#
#
# gece Propagation Learning:
# ‘Apply gradient decent over the entire network
# As before, we have:
# wi
# Aw(it ou Sx(i)"
# “t =-n6
# Som
#
# = (Your ML You Mout ~ Frain)

# %%
img2 = cv2.medianBlur(img, 5)

# %%
plt.imshow(img2)

# %%
print(pytesseract.image_to_string(img2))

# %%
img = cv2.imread('testNoise.jpg', 0)

# %%
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 0.1, 5,
                            param1=50, param2=30, minRadius=0, maxRadius=0)

cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    #cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2.imshow('detected circles', cimg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
circles = cv2.HoughCircles(img2,cv2.HOUGH_GRADIENT,0.1, 5,
                            param1=50,param2=30,minRadius=0,maxRadius=0)

cimg = cv2.cvtColor(img2, cv2.COLOR_GRAY2BGR)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    #cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2.imshow('detected circles',cimg)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('contour.png', 0)

# %%
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 0.1, 5,
                            param1=50, param2=30, minRadius=1, maxRadius=0)

cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2.imshow('detected circles', cimg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
black_filter = np.zeros((10,5))+0.1

# %%
plt.imshow(black_filter)

# %%
print(np.amax(img))
print(np.amin(img))
# Out:
# 255
# 0

# %%
out_img = cv2.filter2D(img, -1, black_filter)

# %%
np.amax(out_img)
# Out:
# 255

# %%
plt.imshow(out_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-23e9b14c1892> in <module>
# ----> 1 plt.imshow(out_img)
#
# NameError: name 'out_img' is not defined

# %%
len(np.where(img > 100)[0])
# Out:
# 1369

# %%
def black_filter(image_, colorthreshold, numthreshold, nrows, ncols):
    new_img = image_.copy()
    
    for r in range(0, image_.shape[0] - nrows, nrows//2):
        for c in range(0, image_.shape[1] - ncols, ncols//2):
            this_chunk = None
            this_chunk = image_[r:r+nrows, c:c+ncols]
            val = 0
            val = len(np.where(this_chunk < colorthreshold)[0])
            
            if (val > numthreshold): #means it is noise
                print(this_chunk.shape, val)
                new_img[r:r+nrows, c:c+ncols] = 255
    return new_img

# %%
out = black_filter(img.copy(), 200, 35, 10, 5)
# Out:
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# (10, 5) 50
# ...

# %%
out.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(out)

# %%
plt.imshow(img)

# %%
n = np.asarray(temp)

# %%
len(np.where(n < 50)[0])
# Out:
# 12

# %%
np.where(n < 50)
# Out:
# (array([0, 0, 0, 0, 0, 0, 1, 1, 2, 2, 2, 2], dtype=int64),
#  array([0, 1, 2, 3, 4, 5, 0, 5, 0, 2, 4, 5], dtype=int64))

# %%
print(pytesseract.image_to_string(out))
# Out:
# + Hidden layer(s) perform classification of features
# * Sigmoid activation function
# ae ?ropagi tion Learning:
#
# ‘Apply gradient decent over the entire network
# As before,
#
#
#
#
#
# x :
# x _néxii)
#
#
#
#  Owli)
#
# = (ya = Ying Wincor Sou a Ae &
#
#
#
# «8 — OV nig Otte,
#
# OU CBee Ving lous ©
#
#
#
#
# lout
#
#
#
#
#
# =x(i)
# owl)
